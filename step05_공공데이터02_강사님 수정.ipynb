# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('dataset/aptPriceDataSet/avg15.09.csv', encoding='utf-8')
# df1

# %%
df01 = pd.read_csv('dataset/aptPriceDataSet/avg15.09.csv', encoding='utf-8', header=1)

# del df01['시도']

df01 = df01.transpose()
df01 = df01.rename(columns=df01.iloc[0])
df01 = df01.drop(df01.index[0])
df01.fillna(0, inplace=True)
df01

# df2['분양가격(㎡)'] = pd.to_numeric(df2['분양가격(㎡)'], errors='coerce')
# Out:
#            NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN     NaN  \
# 시군구         서울     부산     대구      인천     광주     대전     울산  6대광역시      경기
# 12월     18,189  8,111  8,080  10,204  6,098  8,321  8,090  8,151  10,855
# 1월      17,925  8,111  8,080  10,204  7,326  8,321  8,090  8,355  10,855
# 2월      17,925  9,078  8,077  10,408  7,611  8,321  8,090  8,597  10,791
# 3월      18,016  8,965  8,101  10,408  7,346  8,341  8,153  8,552  10,784
# 4월      18,098  9,402  8,267  10,000  7,346  8,341  8,153  8,585  10,876
# 5월      19,446  9,501  8,274   9,844  7,523  8,341  8,153  8,606  10,646
# 6월      18,867  9,453  8,360  10,058  7,659  8,333  8,153  8,669  10,266
# 7월      18,742  9,457  8,360   9,974  7,612  8,333  8,153  8,648  10,124
# 8월      19,274  9,411  8,370   9,973  7,622  8,333  8,493  8,700  10,134
# 9월      19,404  9,258  8,449   9,973  7,802  8,048  8,493  8,671  10,501
# 10월     19,759  9,110  8,403  10,016  7,707  8,038  8,627  8,650  10,397
# ...

# %%
df2['분양가격(㎡)'] = pd.to_numeric(df2['분양가격(㎡)'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-891c5a2f9649> in <module>
# ----> 1 df2['분양가격(㎡)'] = pd.to_numeric(df2['분양가격(㎡)'], errors='coerce')
#
# NameError: name 'df2' is not defined

# %%
df01['서울'].dtypes
# Out:
# dtype('O')

# %%
type(df01['서울'])
# Out:
# pandas.core.series.Series

# %%
df01['서울']
# Out:
# Unnamed: 1           0
# Unnamed: 2      18,189
# Unnamed: 3      17,925
# Unnamed: 4      17,925
# Unnamed: 5      18,016
# Unnamed: 6      18,098
# Unnamed: 7      19,446
# Unnamed: 8      18,867
# Unnamed: 9      18,742
# Unnamed: 10     19,274
# Unnamed: 11     19,404
# Unnamed: 12     19,759
# Unnamed: 13     20,242
# Unnamed: 14     20,269
# Unnamed: 15     20,670
# Unnamed: 16     20,670
# Unnamed: 17     19,415
# Unnamed: 18     18,842
# Unnamed: 19     18,367
# Unnamed: 20     18,374
# Unnamed: 21     18,152
# Unnamed: 22     18,443
# Unnamed: 23     17,969
# Unnamed: 24      -474
# Unnamed: 25    -2,300
# Unnamed: 26    -1,434
# Name: 서울, dtype: object

# %%
# df01['서울'].strip()
df01['서울'] = df01['서울'].str.strip()

# %%
df01['서울'] = df01['서울'].str.replace(',', '')

# %%
df01['서울']
# Out:
# Unnamed: 1       NaN
# Unnamed: 2     18189
# Unnamed: 3     17925
# Unnamed: 4     17925
# Unnamed: 5     18016
# Unnamed: 6     18098
# Unnamed: 7     19446
# Unnamed: 8     18867
# Unnamed: 9     18742
# Unnamed: 10    19274
# Unnamed: 11    19404
# Unnamed: 12    19759
# Unnamed: 13    20242
# Unnamed: 14    20269
# Unnamed: 15    20670
# Unnamed: 16    20670
# Unnamed: 17    19415
# Unnamed: 18    18842
# Unnamed: 19    18367
# Unnamed: 20    18374
# Unnamed: 21    18152
# Unnamed: 22    18443
# Unnamed: 23    17969
# Unnamed: 24     -474
# Unnamed: 25    -2300
# Unnamed: 26    -1434
# Name: 서울, dtype: object

# %%
df01['서울'].astype(str)
# Out:
# Unnamed: 1        nan
# Unnamed: 2     18,189
# Unnamed: 3     17,925
# Unnamed: 4     17,925
# Unnamed: 5     18,016
# Unnamed: 6     18,098
# Unnamed: 7     19,446
# Unnamed: 8     18,867
# Unnamed: 9     18,742
# Unnamed: 10    19,274
# Unnamed: 11    19,404
# Unnamed: 12    19,759
# Unnamed: 13    20,242
# Unnamed: 14    20,269
# Unnamed: 15    20,670
# Unnamed: 16    20,670
# Unnamed: 17    19,415
# Unnamed: 18    18,842
# Unnamed: 19    18,367
# Unnamed: 20    18,374
# Unnamed: 21    18,152
# Unnamed: 22    18,443
# Unnamed: 23    17,969
# Unnamed: 24      -474
# Unnamed: 25    -2,300
# Unnamed: 26    -1,434
# Name: 서울, dtype: object

# %%
type(df01['서울'])
# Out:
# pandas.core.series.Series

# %%
df01['서울'] = df01['서울'].fillna(0)
df01['서울']
# Out:
# Unnamed: 1         0
# Unnamed: 2     18189
# Unnamed: 3     17925
# Unnamed: 4     17925
# Unnamed: 5     18016
# Unnamed: 6     18098
# Unnamed: 7     19446
# Unnamed: 8     18867
# Unnamed: 9     18742
# Unnamed: 10    19274
# Unnamed: 11    19404
# Unnamed: 12    19759
# Unnamed: 13    20242
# Unnamed: 14    20269
# Unnamed: 15    20670
# Unnamed: 16    20670
# Unnamed: 17    19415
# Unnamed: 18    18842
# Unnamed: 19    18367
# Unnamed: 20    18374
# Unnamed: 21    18152
# Unnamed: 22    18443
# Unnamed: 23    17969
# Unnamed: 24     -474
# Unnamed: 25    -2300
# Unnamed: 26    -1434
# Name: 서울, dtype: object

# %%
df01['서울'] = pd.to_numeric(df01['서울'], errors='coerce')
df01['서울']
# Out:
# Unnamed: 1         0
# Unnamed: 2     18189
# Unnamed: 3     17925
# Unnamed: 4     17925
# Unnamed: 5     18016
# Unnamed: 6     18098
# Unnamed: 7     19446
# Unnamed: 8     18867
# Unnamed: 9     18742
# Unnamed: 10    19274
# Unnamed: 11    19404
# Unnamed: 12    19759
# Unnamed: 13    20242
# Unnamed: 14    20269
# Unnamed: 15    20670
# Unnamed: 16    20670
# Unnamed: 17    19415
# Unnamed: 18    18842
# Unnamed: 19    18367
# Unnamed: 20    18374
# Unnamed: 21    18152
# Unnamed: 22    18443
# Unnamed: 23    17969
# Unnamed: 24     -474
# Unnamed: 25    -2300
# Unnamed: 26    -1434
# Name: 서울, dtype: int64

# %%
seoul = pd.DataFrame(df01.iloc[0])
seoul = seoul.rename(columns=seoul.iloc[0])

# %%
df01
# Out:
#                         구분     시도     전국     서울  6대광역시    NaN     NaN    NaN  \
# Unnamed: 1               0    시군구      0    0.0     부산     대구      인천     광주
# Unnamed: 2           2013년    12월  8,059    NaN  8,111  8,080  10,204  6,098
# Unnamed: 3           2014년     1월  8,130    NaN  8,111  8,080  10,204  7,326
# Unnamed: 4               0     2월  8,195    NaN  9,078  8,077  10,408  7,611
# Unnamed: 5               0     3월  8,204    NaN  8,965  8,101  10,408  7,346
# Unnamed: 6               0     4월  8,289    NaN  9,402  8,267  10,000  7,346
# Unnamed: 7               0     5월  8,358    NaN  9,501  8,274   9,844  7,523
# Unnamed: 8               0     6월  8,344    NaN  9,453  8,360  10,058  7,659
# Unnamed: 9               0     7월  8,333    NaN  9,457  8,360   9,974  7,612
# Unnamed: 10              0     8월  8,395    NaN  9,411  8,370   9,973  7,622
# Unnamed: 11              0     9월  8,459    NaN  9,258  8,449   9,973  7,802
# ...

# %%
df2 = pd.read_csv('../dataset/aptPriceDataSet/avg18.07.csv', encoding='utf-8')

df2
# df2['분양가격(3.3㎡)'] = 0
# df2['분양가격(㎡)'].replace(np.nan,0)
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)
# 0     서울                 전체  2015  10    5841
# 1     서울         전용면적 60㎡이하  2015  10    5652
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4     서울        전용면적 102㎡초과  2015  10    5879
# ...   ..                ...   ...  ..     ...
# 2885  제주                 전체  2018   7    3334
# 2886  제주         전용면적 60㎡이하  2018   7     NaN
# 2887  제주   전용면적 60㎡초과 85㎡이하  2018   7    3356
# 2888  제주  전용면적 85㎡초과 102㎡이하  2018   7    3226
# 2889  제주        전용면적 102㎡초과  2018   7    2990
#
# [2890 rows x 5 columns]

# %%
df2.tail(10)

df2['분양가격(㎡)'] = pd.to_numeric(df2['분양가격(㎡)'], errors='coerce')

# %%
df2.fillna(0, inplace=True)
df2

df2['분양가격(3.3㎡)'] = df2['분양가격(㎡)']*3.3
df2
# Out:
#      지역명               규모구분    연도   월  분양가격(㎡)  분양가격(3.3㎡)
# 0     서울                 전체  2015  10   5841.0     19275.3
# 1     서울         전용면적 60㎡이하  2015  10   5652.0     18651.6
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10   5882.0     19410.6
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10   5721.0     18879.3
# 4     서울        전용면적 102㎡초과  2015  10   5879.0     19400.7
# ...   ..                ...   ...  ..      ...         ...
# 2885  제주                 전체  2018   7   3334.0     11002.2
# 2886  제주         전용면적 60㎡이하  2018   7      0.0         0.0
# 2887  제주   전용면적 60㎡초과 85㎡이하  2018   7   3356.0     11074.8
# 2888  제주  전용면적 85㎡초과 102㎡이하  2018   7   3226.0     10645.8
# 2889  제주        전용면적 102㎡초과  2018   7   2990.0      9867.0
#
# [2890 rows x 6 columns]

# %%
df1.columns
# Out:
# Index(['□ 평균 분양가격', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26'],
#       dtype='object')

# %%
a1 = df2['지역명'] == '세종'
# a2 = df2['연도'] == 2015

df2[a1]
# Out:
#      지역명               규모구분    연도   월  분양가격(㎡)  분양가격(3.3㎡)
# 40    세종                 전체  2015  10   2642.0      8718.6
# 41    세종         전용면적 60㎡이하  2015  10   2572.0      8487.6
# 42    세종   전용면적 60㎡초과 85㎡이하  2015  10   2657.0      8768.1
# 43    세종  전용면적 85㎡초과 102㎡이하  2015  10   2644.0      8725.2
# 44    세종        전용면적 102㎡초과  2015  10   2692.0      8883.6
# ...   ..                ...   ...  ..      ...         ...
# 2845  세종                 전체  2018   7   3131.0     10332.3
# 2846  세종         전용면적 60㎡이하  2018   7   3064.0     10111.2
# 2847  세종   전용면적 60㎡초과 85㎡이하  2018   7   3147.0     10385.1
# 2848  세종  전용면적 85㎡초과 102㎡이하  2018   7   3138.0     10355.4
# 2849  세종        전용면적 102㎡초과  2018   7   3135.0     10345.5
#
# [170 rows x 6 columns]

# %%
area = pd.DataFrame([{'규모구분':'전체', '등급':'A'},{'규모구분':'전용면적 60㎡이하', '등급':'B'},{'규모구분':'전용면적 60㎡초과 85㎡이하', '등급':'C'},
                     {'규모구분':'전용면적 85㎡초과 102㎡이하', '등급':'D'},{'규모구분':'전용면적 102㎡초과', '등급':'E'}])

area
# Out:
#                 규모구분 등급
# 0                 전체  A
# 1         전용면적 60㎡이하  B
# 2   전용면적 60㎡초과 85㎡이하  C
# 3  전용면적 85㎡초과 102㎡이하  D
# 4        전용면적 102㎡초과  E

# %%
df3 = pd.merge(df2,area,on='규모구분')
df3
# Out:
#      지역명         규모구분    연도   월  분양가격(㎡)  분양가격(3.3㎡) 등급
# 0     서울           전체  2015  10   5841.0     19275.3  A
# 1     인천           전체  2015  10   3163.0     10437.9  A
# 2     경기           전체  2015  10   3138.0     10355.4  A
# 3     부산           전체  2015  10   3112.0     10269.6  A
# 4     대구           전체  2015  10   2682.0      8850.6  A
# ...   ..          ...   ...  ..      ...         ... ..
# 2885  전북  전용면적 102㎡초과  2018   7   2850.0      9405.0  E
# 2886  전남  전용면적 102㎡초과  2018   7   2469.0      8147.7  E
# 2887  경북  전용면적 102㎡초과  2018   7   2903.0      9579.9  E
# 2888  경남  전용면적 102㎡초과  2018   7   2839.0      9368.7  E
# 2889  제주  전용면적 102㎡초과  2018   7   2990.0      9867.0  E
#
# [2890 rows x 7 columns]
